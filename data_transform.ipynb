# %%
# !pip install tensorflow==2.5.1
# tensorflow 2.5.1 버전만 가능
# Out:
# ...
#      |████████████████████████████████| 454.4 MB 8.8 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 36.6 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 39.6 MB/s
# ...
#      |████████████████████████████████| 462 kB 52.3 MB/s
# ...
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.41.0
#     Uninstalling grpcio-1.41.0:
#       Successfully uninstalled grpcio-1.41.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# ...

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.5.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: keras-preprocessing, grpcio, astunparse, protobuf, gast, wrapt, flatbuffers, tensorboard, absl-py, tensorflow-estimator, typing-extensions, wheel, termcolor, numpy, keras-nightly, six, opt-einsum, google-pasta, h5py
# Required-by: kapre

# %% [markdown]
# 학습된 weights를 Django에서 연결 할 수 있도록 tensorflow로 변환
#
# 1. tensorflow_yolo_tflite 라이브러리를 clone
#   - (https://github.com/hunglc007/tensorflow-yolov4-tflite.git)
# 2. tensroflow_yolo_tflite 경로를 PYHONPATH 환경변수로 설정
#   - (C:\2021_2nd_lab\05.object_detection\lion_tiger_yolo_tensorflow\tensorflow-yolov4-tflite)
#   - 경로는 개인에게 맞게 설정
#
# 3. core/config.py 의 C.YOLO.CLASSES 에 names 파일 경로 설정
#
# 4. darknet으로 train 한 weight를 tensorflow 모델로 convert (./checkpoints/yolo-416)
#
# * detect.py 코드를 참고해서 detection 하는 코드를 작성

# %% [markdown]
# - names 파일을 작성
#     - data/classes/obj.names : 1++, 1+, 1, 2, 3 등록
# - core/config.py
#     - C.YOLO.CLASSES 변수의 경로를 obj.names로 변경
# - yolo3_best.weight를 tensorflow keras모델로 convert
#     - tensorflow_yolo_tflite/checkpoints/yolo-lion-tiger
#     - `python save_model.py --weights ./pretrained_weights/yolov4_best.weights --output ./checkpoints/yolo-lion-tiger --input_size 416`

# %%
# !git clone https://github.com/hunglc007/tensorflow-yolov4-tflite.git
# Out:
# Cloning into 'tensorflow-yolov4-tflite'...
# remote: Enumerating objects: 790, done.
# remote: Total 790 (delta 0), reused 0 (delta 0), pack-reused 790
# Receiving objects: 100% (790/790), 197.64 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (373/373), done.

# %%
# !cp -r /content/tensorflow-yolov4-tflite /content/drive/MyDrive/object_detection_final/YOLO

# %%
import os

os.environ['PYTHONPATH'] += ":/content/drive/MyDrive/object_detection_final/YOLO/tensorflow-yolov4-tflite/"

# %%
os.environ['PYTHONPATH']
# Out:
# '/env/python:/content/drive/MyDrive/object_detection_final/YOLO/tensorflow-yolov4-tflite/'

# %%
WEIGHTS_FILE_PATH = "/content/drive/MyDrive/object_detection_final/YOLO/workspace/weight_backup/yolov4_best.weights"
OUTPUT_FILE_PATH = "/content/drive/MyDrive/object_detection_final/YOLO/trans_weights"

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/object_detection_final/YOLO/tensorflow-yolov4-tflite/
# Out:
# /content/drive/MyDrive/object_detection_final/YOLO/tensorflow-yolov4-tflite

# %%
from core import utils
from core.yolov4 import filter_boxes

# %%
# !ls
# Out:
# android		    core	    LICENSE		  result-int8.png
# benchmarks.py	    data	    mAP			  result.png
# CODE_OF_CONDUCT.md  detect.py	    README.md		  save_model.py
# convert_tflite.py   detectvideo.py  requirements-gpu.txt  scripts
# convert_trt.py	    evaluate.py     requirements.txt	  train.py

# %%
# !python save_model.py --weights /content/drive/MyDrive/object_detection_final/YOLO/workspace/weight_backup/yolov4_best.weights --output /content/drive/MyDrive/object_detection_final/YOLO/trans_weights --input_size 512
# Out:
# 2021-10-25 06:31:05.459910: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-25 06:31:07.640894: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-10-25 06:31:07.653639: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-25 06:31:07.653701: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (8dfb8d549546): /proc/driver/nvidia/version does not exist
# 2021-10-25 06:31:07.654086: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
# !ls /content/drive/MyDrive/object_detection_final/YOLO/workspace/weight_backup/yolov4_best.weights
# Out:
# /content/drive/MyDrive/object_detection_final/YOLO/workspace/weight_backup/yolov4_best.weights
